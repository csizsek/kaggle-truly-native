# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from matplotlib import pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = pd.read_csv('tmp/0.csv', header=False)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 98
# Data columns (total 33 columns):
# 1266840_raw_html.txt    99 non-null object
# 64                      99 non-null int64
# 9                       99 non-null int64
# 54                      99 non-null int64
# 17                      99 non-null int64
# 37                      99 non-null int64
# 8                       99 non-null int64
# 0                       99 non-null int64
# 17.1                    99 non-null int64
# 33                      99 non-null int64
# 4                       99 non-null int64
# 47                      99 non-null int64
# 17.2                    99 non-null int64
# 3                       99 non-null int64
# 14                      99 non-null int64
# 2                       99 non-null int64
# 0.1                     99 non-null int64
# 13                      99 non-null int64
# 5                       99 non-null int64
# 1358                    99 non-null int64
# ...

# %%
d.describe().T
# Out:
#                count         mean           std  min         25%         50%  \
# 64                99  1780.343434  17087.886108    4   43.500000    60.00000
# 9                 99   850.070707   8354.436700    1    7.000000    10.00000
# 54                99   118.919192    111.182941    0   42.500000    88.00000
# 17                99    43.797980     82.653689    0    2.000000     9.00000
# 37                99    75.121212     76.448765    0   13.500000    52.00000
# 8                 99    67.989899     76.684684    0   11.000000    44.00000
# 0                 99     2.505051     13.162543    0    0.000000     0.00000
# 17.1              99    45.777778     86.557231    0    2.000000     9.00000
# 33                99    65.808081     74.097382    0    9.000000    39.00000
# 4                 99     5.505051      9.872011    0    0.000000     2.00000
# 47                99   109.616162    103.204444    0   37.500000    81.00000
# ...
